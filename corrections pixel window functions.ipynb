# %%
import matplotlib.pyplot as plt
import numpy as np
import healpy as hp

# %%
hp.sphtfunc.pixwin(nside=32, lmax=32)
# Out:
# array([1.        , 0.99990902, 0.99972708, 0.99945423, 0.99909052,
#        0.99863604, 0.99809089, 0.99745519, 0.99672908, 0.99591274,
#        0.99500635, 0.99401011, 0.99292424, 0.991749  , 0.99048464,
#        0.98913146, 0.98768975, 0.98615985, 0.98454209, 0.98283684,
#        0.98104449, 0.97916544, 0.9772001 , 0.97514893, 0.97301237,
#        0.97079091, 0.96848504, 0.96609529, 0.96362217, 0.96106625,
#        0.95842809, 0.95570827, 0.95290741])

# %%
plt.plot(hp.sphtfunc.pixwin(nside=32, lmax=32))
